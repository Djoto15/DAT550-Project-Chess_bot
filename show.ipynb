# %% [markdown]
# # Importation

# %%
from bot import RandomBot, Stockfish, Classifier, Regression
from evaluation import Evaluation
from engine import Engine

# %% [markdown]
# # Bot creation

# %%
engine = Engine()
classifier_bot = Classifier(engine, "white")
regressor_bot = Regression(engine)
stockfish_bot = Stockfish(engine, elo=200)

# %% [markdown]
# # Training

# %%
PGN_PATH = "data/1800thresh_1448.pgn"

# %%
classifier_bot.fit(PGN_PATH)
# Out:
# Started training...
# ...
# Training progress: 100%|██████████| 1448/1448 [00:07<00:00, 183.74game/s]
# Bot training finished. Trained on 54037 moves from 1448 games.

# %%
regressor_bot.fit(PGN_PATH)
# Out:
# Training Progress: 100%|██████████| 1448/1448 [00:25<00:00, 56.26it/s]

# %% [markdown]
# # Evaluation

# %%
evaluator = Evaluation(engine, white_player=classifier_bot, black_player=regressor_bot)

# %% [markdown]
# ### Classifier as white and Regressor as black

# %%
# Evaluate game
scores = evaluator.play_game()
# print(scores)
evaluator.draw_scores(scores)
# stockfish_bot.close()
# Out:
# Game has begun...
# Game is finished.

# %% [markdown]
# ### Classifier as white and Stockfish as black

# %%
evaluator2 = Evaluation(engine, white_player=classifier_bot, black_player=stockfish_bot)

# %%
# Evaluate game
scores2 = evaluator2.play_game()
# print(scores)
evaluator2.draw_scores(scores2)
stockfish_bot.close()
# Out:
# Game has begun...
# Game is finished.
